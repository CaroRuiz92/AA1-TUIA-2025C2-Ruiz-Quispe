# %% [markdown]
# ## Trabajo Práctico
# ### Aprendizaje Automático I

# %% [markdown]
# #### Carga de librerías necesarias

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler   # u otros scalers
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, LassoCV, RidgeCV, ElasticNetCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# #### Carga de datos

# %%
file_path = 'uber_fares.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# #### Contexto
# El proyecto trata sobre **Uber Inc.**, la compañía de taxis más grande del mundo. En este trabajo, nuestro objetivo es **predecir la tarifa de futuros viajes**.
#
# Uber brinda servicio a millones de clientes cada día, por lo que gestionar adecuadamente sus datos es clave para desarrollar nuevas estrategias de negocio y obtener mejores resultados.
#
# #### Variables del conjunto de datos
#
# **Variables explicativas:**
# - **key**: identificador único de cada viaje.
# - **pickup_datetime**: fecha y hora en que se inició el viaje.
# - **passenger_count**: cantidad de pasajeros en el vehículo (dato ingresado por el conductor).
# - **pickup_longitude**: longitud del punto de inicio del viaje.
# - **pickup_latitude**: latitud del punto de inicio del viaje.
# - **dropoff_longitude**: longitud del punto de destino.
# - **dropoff_latitude**: latitud del punto de destino.
#
# **Variable objetivo (target):**
# - **fare_amount**: costo del viaje en dólares.

# %% [markdown]
# Visualización general del dataset.

# %%
df.head()
# Out:
#         key                           date  fare_amount  \
# 0  24238194    2015-05-07 19:52:06.0000003          7.5
# 1  27835199    2009-07-17 20:04:56.0000002          7.7
# 2  44984355   2009-08-24 21:45:00.00000061         12.9
# 3  25894730    2009-06-26 08:22:21.0000001          5.3
# 4  17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# ...

# %% [markdown]
# #### **Visualización de los datos** (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                200000 non-null  int64
#  1   date               200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %% [markdown]
# Se observan muy pocos datos nulos en las columnas relacionadas a la bajada de los viajes. Se continúa con las métricas generales de las columnas numéricas.

# %%
df.describe()
# Out:
#                 key    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# ...

# %% [markdown]
# Siendo que la variable objetivo es **fare_amount**, y observando que tiene datos negativos, se decide eliminarlos ya que no hay una manera viable de imputarlos.

# %%
df = df[df['fare_amount']>=0]

# %% [markdown]
# Se continúa con los valores nulos para luego eliminarlos.

# %%
df[df.isna().any(axis=1)]
# Out:
#             key                         date  fare_amount  \
# 87946  32736015  2013-07-02 03:51:57.0000001         24.1
#
#                pickup_datetime  pickup_longitude  pickup_latitude  \
# 87946  2013-07-02 03:51:57 UTC        -73.950581        40.779692
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# 87946                NaN               NaN                0

# %%
df = df.dropna()

# %% [markdown]
# Ya que se eliminaron datos nulos relacionados a latitudes y longitudes, se procede a visualizar las ubicaciones de bajadas y subidas de los viajes hechos.

# %%
info_mapeo = df[['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']]

# %%
import geopandas as gpd
import contextily as ctx

# %%
# GeoDataFrame de pickups y dropoffs
gdf_pickup = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(info_mapeo['pickup_longitude'], info_mapeo['pickup_latitude']), crs="EPSG:4326")
gdf_dropoff = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(info_mapeo['dropoff_longitude'], info_mapeo['dropoff_latitude']), crs="EPSG:4326")

# Proyección métrica
gdf_pickup = gdf_pickup.to_crs(epsg=3857)
gdf_dropoff = gdf_dropoff.to_crs(epsg=3857)

fig, ax = plt.subplots(figsize=(10, 14))
gdf_pickup.plot(ax=ax, markersize=2, color="blue", alpha=0.5, label="Subidas")
gdf_dropoff.plot(ax=ax, markersize=2, color="red", alpha=0.5, label="Bajadas")

# Mapa base
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)

plt.legend()
plt.title("Viajes hechos sobre mapa real")
plt.show()

# %% [markdown]
# El mapa demuestra que muchos viajes pertenecen a zonas geográficas variadas. Posiblemente el dataset mezcló viajes de distintos paises, por error. Por razones de practicidad, solo se seleccionarán viajes hechos dentro de territorio de New York ya que en principio, el trabajo debería limitarse a esa zona.
# Se tendrán en cuenta estos datos para la selección nueva:
# - Latitud: entre 40 y 41 grados.
# - Longitud: entre -75 y -72 grados.

# %%
def in_ny(lat, lon):
    return 40 <= lat <= 41 and -75 <= lon <= -72

# Filtro pickups
mask_pickup = df.apply(lambda row: in_ny(row['pickup_latitude'], row['pickup_longitude']), axis=1)

# Filtro dropoffs
mask_dropoff = df.apply(lambda row: in_ny(row['dropoff_latitude'], row['dropoff_longitude']), axis=1)

# Se guardan viajes donde pickup y dropoff están en USA
df_ny = df[mask_pickup & mask_dropoff].copy()

# %%
print(f'El dataset original tiene {len(df)} registros. El dataset, tiene {len(df_ny)}. Por lo tanto, se eliminaron {len(df)-len(df_ny)} registros.')
# Out:
# El dataset original tiene 199982 registros. El dataset, tiene 195681. Por lo tanto, se eliminaron 4301 registros.

# %% [markdown]
# #### **Creación de nuevas variables**

# %% [markdown]
# Se adecúan los tipos de datos para la creación de columnas relacionadas al tiempo y la distancia.

# %%
df_ny['pickup_datetime'] = pd.to_datetime(df_ny['pickup_datetime'], utc=True)

# %% [markdown]
# Para evitar datos redundantes, se elimina la columna **date**. También **key**, al ser irrelevante.

# %%
df_ny = df_ny.drop(columns=['date', 'key'])

# %% [markdown]
# Para descartar ideas a la hora de crear variables nuevas, se visualizan las variaciones de **fare_amount** con respecto a la hora y el día de la semana.

# %%
prov = df_ny.copy()

# %%
prov['hora'] = prov['pickup_datetime'].dt.hour

# %%
tarifa_hora = prov.groupby('hora')['fare_amount'].mean()
tarifa_hora.head(24)
# Out:
# hora
# 0     11.581566
# 1     11.599465
# 2     11.349119
# 3     11.592307
# 4     14.038949
# 5     16.010885
# 6     11.939965
# 7     11.092011
# 8     10.888377
# 9     10.977347
# 10    10.985954
# 11    11.203856
# 12    11.166540
# 13    11.439133
# 14    11.971845
# 15    11.895739
# 16    11.781528
# 17    11.466837
# 18    10.890343
# 19    10.514909
# 20    10.743404
# 21    10.939850
# 22    11.288317
# 23    11.556880
# Name: fare_amount, dtype: float64

# %%
tarifa_hora.plot(kind='bar', figsize=(6, 5), color='skyblue', edgecolor='black')
# Out:
# <Axes: xlabel='hora'>

# %% [markdown]
# Teniendo en cuenta el cálculo agrupado y el gráfico anterior, la variación más significativa se produce entre las 4 y 5 de la madrugada. El resto del día se mantiene bastante estable. Sin embargo, también se podrían considerar destacables las franjas de 00 a 03 y 14 a 16. Se tendrá en cuenta para dummies.

# %%
prov['dia'] = prov['pickup_datetime'].dt.dayofweek

# %%
tarifa_dia = prov.groupby('dia')['fare_amount'].mean()
tarifa_dia.head(7)
# Out:
# dia
# 0    11.368981
# 1    11.069720
# 2    11.330677
# 3    11.478998
# 4    11.397170
# 5    10.998381
# 6    11.716066
# Name: fare_amount, dtype: float64

# %%
tarifa_dia = prov.groupby('dia')['fare_amount'].mean()
tarifa_dia.plot(kind='bar', figsize=(6,4), color='skyblue', edgecolor='black')
# Out:
# <Axes: xlabel='dia'>

# %% [markdown]
# El promedio de la tarifa por día no parece tener una gran variación por día, salvo levemente por los domingos. Se evaluará si realmente tiene impacto para un modelo predictivo.

# %%
prov['quincena'] = prov['pickup_datetime'].dt.day.apply(lambda d: 1 if d <= 15 else 2)

# %%
tarifa_quincena = prov.groupby('quincena')['fare_amount'].mean()
tarifa_quincena.head()
# Out:
# quincena
# 1    11.315992
# 2    11.347475
# Name: fare_amount, dtype: float64

# %% [markdown]
# Asimismo, la quincena del mes en el que se ubica el viaje tampoco parece tener relevancia. Se descarta para hacer dummies.

# %% [markdown]
# Se crea una columna para conocer bien los KMs hechos por viaje.

# %%
def manhattan_distance(lat1, lon1, lat2, lon2):
    R_lat = 111.32  # Aproximación de grados a km en latitud
    R_lon = 111.32  # Aproximación de grados a km en longitud

    dlat = np.abs(lat2 - lat1)
    dlon = np.abs(lon2 - lon1)

    dist_lat = R_lat * dlat
    dist_lon = R_lon * dlon

    return dist_lat + dist_lon

df_ny['KMs'] = manhattan_distance(
    df_ny['pickup_latitude'], df_ny['pickup_longitude'],
    df_ny['dropoff_latitude'], df_ny['dropoff_longitude'])

# %% [markdown]
# Se chequea cómo son las métricas del dataset actualizado.

# %%
df_ny.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  195681.000000     195681.000000    195681.000000      195681.000000
# mean       11.331933        -73.975454        40.750728         -73.974486
# std         9.716312          0.035720         0.027574           0.035852
# min         0.000000        -74.719883        40.002405         -74.728123
# 25%         6.000000        -73.992277        40.736446         -73.991600
# 50%         8.500000        -73.982114        40.753295         -73.980545
# 75%        12.500000        -73.968385        40.767519         -73.965418
# max       499.000000        -72.750302        40.991651         -72.759090
#
#        dropoff_latitude  passenger_count            KMs
# count     195681.000000    195681.000000  195681.000000
# mean          40.751024         1.685028       4.890114
# std            0.031338         1.388005       5.581060
# min           40.005487         0.000000       0.000000
# ...

# %% [markdown]
# Se destaca que **fare_amount** tiene valores en cero. Se cuestiona si son viajes con **KMs** hechos. En el caso de que haya viajes sin tarifa ni kms, se eliminan por no aportar nada al futuro modelo, siendo posiblemente errores.

# %%
df_ny[(df_ny['KMs']==0) & (df_ny['fare_amount']==0)]
# Out:
#        fare_amount           pickup_datetime  pickup_longitude  \
# 20744          0.0 2015-04-22 23:25:07+00:00        -73.658897
#
#        pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 20744        40.805199         -73.658897         40.805199                1
#
#        KMs
# 20744  0.0

# %%
df_ny = df_ny[~((df_ny['KMs'] == 0) & (df_ny['fare_amount'] == 0))]

# %% [markdown]
# Como se sospecha que **KMs** aun puede que tenga valores en cero, se muestra su distribución en un boxplot.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_ny['KMs'])
plt.title('Distribución de KMs')
plt.xlabel('Kilómetros')
plt.show()

# %% [markdown]
# Se confirma la existencia de valores en cero o cerca de cero. Se evalúa más en detalle.

# %%
df_ny['KMs'].describe()
# Out:
# count    195680.000000
# mean          4.890139
# std           5.581063
# min           0.000000
# 25%           1.826761
# 50%           3.133547
# 75%           5.650826
# max          95.598722
# Name: KMs, dtype: float64

# %%
cant_cero = len(df_ny[df_ny['KMs']==0])
print(f'De {len(df_ny)} registros, {cant_cero} cuentan con KMs=0')
# Out:
# De 195680 registros, 1980 cuentan con KMs=0

# %% [markdown]
# Los valores KMs=0 representan apróx. el 1.01% del dataset trabajado. Al ser tan ínfimo, se elige eliminarlos.

# %%
df_ny = df_ny[df_ny['KMs']>0]

# %%
df_ny['KMs'].describe()
# Out:
# count    193700.000000
# mean          4.940126
# std           5.587461
# min           0.000111
# 25%           1.860825
# 50%           3.166163
# 75%           5.695437
# max          95.598722
# Name: KMs, dtype: float64

# %% [markdown]
# Resulta curioso que, si bien se eliminaron los viajes sin KMs hechos, aún persisten registros con menos de un kilómetro hecho. Si bien puede resultar extraño, se opta por dejar los viajes que han hecho al menos 100 metros (0.1 KMs), al ser solo una cuadra.

# %%
df_ny = df_ny[df_ny['KMs'] > 0.1]

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_ny['KMs'])
plt.title('Distribución de KMs')
plt.xlabel('Kilómetros')
plt.show()

# %% [markdown]
# **Creación de dummies**

# %% [markdown]
# Se agregan columnas relacionadas a días (y si el viaje se produjo un domingo o no) y horas (y si se produjo en el pico encontrado o en las otras franjas destacadas), ya que se consideran valores importantes para el modelo predictivo buscado.

# %%
df_ny['hour'] = df_ny['pickup_datetime'].dt.hour   # variable provisaria
df_ny['day'] = df_ny['pickup_datetime'].dt.dayofweek   # variable provisoria
df_ny['es_domingo'] = df_ny['day'] == 6

# %%
condic_hora = [
    (df_ny['hour']>=0) & (df_ny['hour']<=3),
    (df_ny['hour']>=4) & (df_ny['hour']<=5),
    (df_ny['hour']>=14) & (df_ny['hour']<=16)
]
valores = ['resto_madrugada', 'pico_madrugada', 'pico_tarde']

df_ny['franja_hora'] = np.select(condic_hora, valores, default='resto_horas')

# %%
df_ny = df_ny.drop(columns=['hour'])

# %% [markdown]
# Tras una breve investigación externa, se llegó a la conclusión de que la variable **passenger_count** si bien aparece como numérica, en realidad se puede tomar como categórica. La cantidad de pasajeros solo define si el viaje implica el uso de un auto normal o un auto más amplio. Por esta razón, se procede a transformarla en dummies más acordes.
# - Paquetería = 0 pasajeros
# - UberX = 1 a 4 pasajeros
# - UberXL = 5 o más pasajeros.

# %%
condiciones = [
    (df_ny['passenger_count'] == 0),
    (df_ny['passenger_count'] >=5)
]
valores = ['paqueteria', 'uberxl']

df_ny['tipo_viaje'] = np.select(condiciones, valores, default='uberx')

# %%
df_ny = df_ny.drop(columns=['passenger_count'])

# %% [markdown]
# Se transforman las variables nuevas a dummies.

# %%
df_dummies = df_ny.copy()

# %%
dummies_tipo = pd.get_dummies(df_dummies['tipo_viaje'], prefix='tipo_viaje', drop_first=False)
df_dummies = pd.concat([df_dummies, dummies_tipo], axis=1)

# %%
dummies_franja = pd.get_dummies(df_dummies['franja_hora'], prefix='franja', drop_first=True)
df_dummies = pd.concat([df_dummies, dummies_franja], axis=1)

# %%
df_dummies = df_dummies.drop(columns=['tipo_viaje', 'franja_hora'])

# %%
df_dummies = df_dummies.drop(columns=['pickup_datetime', 'day'])

# %% [markdown]
# Se guarda en un dataframe nuevo la versión final que se usará en el modelo.

# %%
df_final = df_dummies.copy()

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 192724 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   fare_amount             192724 non-null  float64
#  1   pickup_longitude        192724 non-null  float64
#  2   pickup_latitude         192724 non-null  float64
#  3   dropoff_longitude       192724 non-null  float64
#  4   dropoff_latitude        192724 non-null  float64
#  5   KMs                     192724 non-null  float64
#  6   es_domingo              192724 non-null  bool
#  7   tipo_viaje_paqueteria   192724 non-null  bool
#  8   tipo_viaje_uberx        192724 non-null  bool
#  9   tipo_viaje_uberxl       192724 non-null  bool
#  10  franja_pico_tarde       192724 non-null  bool
#  11  franja_resto_horas      192724 non-null  bool
#  12  franja_resto_madrugada  192724 non-null  bool
# dtypes: bool(7), float64(6)
# memory usage: 11.6 MB

# %% [markdown]
# Al ya tener una columna de **KMs** se considera que las columnas de longitudes y latitudes no son tan útiles para el modelo. Se eliminan antes de la matríz de correlación.

# %%
df_final = df_final.drop(columns=['pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude'])

# %% [markdown]
# **Correlaciones entre variables candidatas**

# %%
matriz_corr = df_final.corr()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(matriz_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlaciones entre variables seleccionadas')
plt.show()

# %% [markdown]
# #### División de dataset a train y test

# %%
y = df_final['fare_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_final.drop(columns='fare_amount'), df_final['fare_amount'], test_size=0.2, random_state=42)

# %%
print(f'Tamaño de X_train {X_train.shape}; tamaño de X_test: {X_test.shape}')
# Out:
# Tamaño de X_train (154179, 8); tamaño de X_test: (38545, 8)

# %% [markdown]
# **Examinación de estructura y contenido de variables de X_train**

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154179 entries, 70406 to 126593
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   KMs                     154179 non-null  float64
#  1   es_domingo              154179 non-null  bool
#  2   tipo_viaje_paqueteria   154179 non-null  bool
#  3   tipo_viaje_uberx        154179 non-null  bool
#  4   tipo_viaje_uberxl       154179 non-null  bool
#  5   franja_pico_tarde       154179 non-null  bool
#  6   franja_resto_horas      154179 non-null  bool
#  7   franja_resto_madrugada  154179 non-null  bool
# dtypes: bool(7), float64(1)
# memory usage: 3.4 MB

# %% [markdown]
# Al ser una columna posiblemente muy influyente, se evalúa la distribución de **KMs**.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=X_train['KMs'])
plt.title('Distribución de KMs')
plt.xlabel('Kilómetros')
plt.show()

# %% [markdown]
# Se mantiene lo visto en la etapa de limpieza: muchos outliers. Sin embargo, pueden ser normales dado el hecho de que el dataset presenta viajes hechos en un territorio muy grande. Sin embargo, se elige escalar los datos para que no afecten estos outliers al modelo.

# %%
scaler = StandardScaler()
X_train['KMs_scaled'] = scaler.fit_transform(X_train[['KMs']])
X_test['KMs_scaled'] = scaler.fit_transform(X_test[['KMs']])

# %% [markdown]
# Se elimina **KMs** parq que no genere problemas en el modelo.

# %%
X_train = X_train.drop(columns=['KMs'])

# %%
X_test = X_test.drop(columns=['KMs'])

# %% [markdown]
# **Validación cruzada**

# %%
from sklearn.model_selection import cross_val_score

# %%
model_cross = LinearRegression()

# %%
# Aplica la validación cruzada
# cv=5 indica que el algoritmo dividirá los datos en 5 subconjuntos (folds)
# scoring='neg_mean_squared_error' te da el MSE, pero con un signo negativo
scores = cross_val_score(model_cross, X_train, y_train, cv=5, scoring='neg_mean_squared_error')

# Muestra los resultados
# `scores` es un array con los 5 resultados de MSE.
print("Resultados de la validación cruzada (MSE):")
print(scores)
print(f"MSE promedio: {-scores.mean():.2f}")
print(f"Desviación estándar del MSE: {scores.std():.2f}")
# Out:
# Resultados de la validación cruzada (MSE):
# [-20.80003779 -19.17176443 -17.74465008 -17.78103999 -18.22036726]
# MSE promedio: 18.74
# Desviación estándar del MSE: 1.15

# %% [markdown]
# #### Modelado Inicial

# %% [markdown]
# Se asegura que todas los columnas cuenten con la misma escala, por lo que se hace un **escalado de X_train**.

# %%
scaler = StandardScaler()
scaler.fit(X_train)

# Transformamos ambos conjuntos usando la media y desv. del train
X_train_scaled = scaler.transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
# Definición y entrenamiento
model = LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Evaluación

# %%
# Predicciones
y_train_pred = model.predict(X_train_scaled)
y_test_pred  = model.predict(X_test_scaled)

# Métricas
def evaluar_modelo(y_true, y_pred, nombre="modelo"):
    mse  = mean_squared_error(y_true, y_pred)
    rmse = mse**0.5
    mae  = mean_absolute_error(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)
    print(f"Resultados {nombre}:")
    print(f"  MSE : {mse:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    print(f"  MAE : {mae:.4f}")
    print(f"  R²  : {r2:.4f}")
    print("-"*40)

evaluar_modelo(y_train, y_train_pred, "LinearRegression (train)")
evaluar_modelo(y_test, y_test_pred, "LinearRegression (test)")
# Out:
# Resultados LinearRegression (train):
#   MSE : 18.7396
#   RMSE: 4.3289
#   MAE : 2.3886
#   R²  : 0.7902
# ----------------------------------------
# Resultados LinearRegression (test):
#   MSE : 18.2834
#   RMSE: 4.2759
#   MAE : 2.3859
#   R²  : 0.7971
# ----------------------------------------

# %% [markdown]
# **Observaciones**: (completar)

# %% [markdown]
# **Prueba con métodos de gradiente descendiente**

# %%
from sklearn.linear_model import SGDRegressor

# %%
m, n = X_train_scaled.shape

# Agregar columna de 1s 
X_train_bias = np.c_[np.ones((m,1)), X_train_scaled] 
X_test_bias = np.c_[np.ones((len(X_test_scaled),1)), X_test_scaled]

# Asegurar que y sean np.array columnas 
y_train = np.asarray(y_train).reshape(-1,1) 
y_test = np.asarray(y_test).reshape(-1,1)

# Inicialización 
theta_batch = np.random.randn(n+1,1) 
theta_sgd = np.random.randn(n+1,1) 
theta_mbgd = np.random.randn(n+1,1)

n_epochs = 50 # bajar épocas para datasets grandes 
eta = 0.1 
batch_size = 64 

errors = {"batch": [], "sgd": [], "minibatch": []}

for epoch in range(n_epochs): 
    # --- Batch GD (solo si no explota memoria) --- 
    grad_batch = 2/m * X_train_bias.T.dot(X_train_bias.dot(theta_batch) - y_train) 
    theta_batch -= eta * grad_batch

    # --- SGD --- 
    i = np.random.randint(m) 
    xi = X_train_bias[i:i+1] 
    yi = y_train[i:i+1] 
    grad_sgd = 2 * xi.T.dot(xi.dot(theta_sgd) - yi) 
    theta_sgd -= eta * grad_sgd 

    # --- Mini-Batch --- 
    indices = np.random.randint(m, size=batch_size) 
    xi = X_train_bias[indices] 
    yi = y_train[indices] 
    grad_mbgd = 2/batch_size * xi.T.dot(xi.dot(theta_mbgd) - yi) 
    theta_mbgd -= eta * grad_mbgd

    # Calcular errores en test 
    y_pred_batch = X_test_bias.dot(theta_batch) 
    y_pred_sgd = X_test_bias.dot(theta_sgd) 
    y_pred_mbgd = X_test_bias.dot(theta_mbgd) 
    
    errors["batch"].append(mean_squared_error(y_test, y_pred_batch)) 
    errors["sgd"].append(mean_squared_error(y_test, y_pred_sgd)) 
    errors["minibatch"].append(mean_squared_error(y_test, y_pred_mbgd))

# Graficar 
plt.plot(range(1, n_epochs+1), errors["batch"], label="Batch GD") 
plt.plot(range(1, n_epochs+1), errors["sgd"], label="SGD") 
plt.plot(range(1, n_epochs+1), errors["minibatch"], label="Mini-Batch GD") 
plt.xlabel("Épocas") 
plt.ylabel("Error (MSE en test)") 
plt.title("Comparación: Batch, SGD y Mini-Batch Gradient Descent") 
plt.legend() 
plt.show()

# %% [markdown]
# **Observaciones:** (CHEQUEAR)
#
# **Batch GD**: es perfectamente plano y se mantiene en un error casi nulo. Esto muestra que el modelo está convergiendo de manera óptima y es totalmente estable.
#
# **Mini-Batch GD**: Al igual que Batch GD, este modelo es ahora completamente estable. Su rendimiento es ideal y muy similar al de Batch GD.
#
# **SGD**: Este modelo sigue siendo muy inestable y su error se dispara a partir de la época 20. Esto sugiere que la tasa de aprendizaje es demasiado alta para este algoritmo, lo que le impide converger.

# %% [markdown]
# **Se prueba con métodos de regularización (Lasso, Ridge, Elastic Net)**

# %%
n_epochs = 50
batch_size = 64
etas = [0.1, 0.01, 0.001]   # diferentes learning rates
decay = 0.001               # para SGD con decaimiento


# Lista de resultados
resultados = []

for eta in etas:
    # Inicialización de parámetros
    theta_batch = np.random.randn(n+1,1)
    theta_sgd   = np.random.randn(n+1,1)
    theta_mbgd  = np.random.randn(n+1,1)

    for epoch in range(n_epochs):
        # ---- Batch GD ----
        grad_batch = 2/m * X_train_bias.T.dot(X_train_bias.dot(theta_batch) - y_train)
        theta_batch -= eta * grad_batch

        # ---- SGD ----
        i = np.random.randint(m)
        xi = X_train_bias[i:i+1]
        yi = y_train[i:i+1]
        eta_epoch = eta / (1 + decay * epoch)  # con scheduler
        grad_sgd = 2 * xi.T.dot(xi.dot(theta_sgd) - yi)
        theta_sgd -= eta_epoch * grad_sgd

        # ---- Mini-Batch GD ----
        indices = np.random.randint(m, size=batch_size)
        xi = X_train_bias[indices]
        yi = y_train[indices]
        grad_mbgd = 2/batch_size * xi.T.dot(xi.dot(theta_mbgd) - yi)
        theta_mbgd -= eta * grad_mbgd


    # Evaluación final

    for modelo, theta in [("Batch GD", theta_batch),
                          ("SGD", theta_sgd),
                          ("Mini-Batch GD", theta_mbgd)]:
        for conj, Xb, yb in [("Train", X_train_bias, y_train),
                             ("Test",  X_test_bias,  y_test)]:
            y_pred = Xb.dot(theta)
            resultados.append({
                "Modelo": modelo,
                "LearningRate": eta,
                "Conjunto": conj,
                "MSE": mean_squared_error(yb, y_pred),
                "RMSE": mean_squared_error(yb, y_pred, squared=False),
                "MAE": mean_absolute_error(yb, y_pred),
                "R²": r2_score(yb, y_pred)
            })


# DataFrame de salida
df_resultados = pd.DataFrame(resultados)
df_resultados = df_resultados.sort_values(by=["Modelo","LearningRate","Conjunto"]).reset_index(drop=True)

# %%
# --- Métricas finales de Gradiente Descendente ---

def calcular_metricas(y_true, y_pred, nombre_modelo):
    return {
        "Modelo": nombre_modelo,
        "R²": r2_score(y_true, y_pred),
        "MSE": mean_squared_error(y_true, y_pred),
        "RMSE": mean_squared_error(y_true, y_pred, squared=False),
        "MAE": mean_absolute_error(y_true, y_pred)
    }

resultados_gd = []

# Predicciones finales de cada método (último theta aprendido)
y_pred_batch = X_test_bias.dot(theta_batch)
y_pred_sgd   = X_test_bias.dot(theta_sgd)
y_pred_mbgd  = X_test_bias.dot(theta_mbgd)

# Guardar métricas
resultados_gd.append(calcular_metricas(y_test, y_pred_batch, "Batch GD"))
resultados_gd.append(calcular_metricas(y_test, y_pred_sgd, "SGD"))
resultados_gd.append(calcular_metricas(y_test, y_pred_mbgd, "Mini-Batch GD"))

# Pasar a DataFrame para ver comparado
df_resultados_gd = pd.DataFrame(resultados_gd)
print(df_resultados_gd)
# Out:
#           Modelo        R²         MSE       RMSE        MAE
# 0       Batch GD -1.212375  199.322195  14.118151  10.472513
# 1            SGD -0.986630  178.983874  13.378485  10.353042
# 2  Mini-Batch GD -1.164244  194.985873  13.963734  11.358350

# %% [markdown]
# **Observaciones**: (completar)

# %% [markdown]
# **Visualización de residuos**

# %% [markdown]
# **Observaciones**: (completar)

# %% [markdown]
# #### Optimización de hiperparámetros

# %% [markdown]
# #### Comparación de modelos
