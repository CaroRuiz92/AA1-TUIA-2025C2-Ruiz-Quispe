# %% [markdown]
# ## Trabajo Práctico
# ### Aprendizaje Automático I

# %% [markdown]
# #### Carga de librerías necesarias

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler   # u otros scalers
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, LassoCV, RidgeCV, ElasticNetCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# #### Carga de datos

# %%
file_path = 'uber_fares.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# Visualización general del dataset.

# %%
df.head()
# Out:
#         key                           date  fare_amount  \
# 0  24238194    2015-05-07 19:52:06.0000003          7.5
# 1  27835199    2009-07-17 20:04:56.0000002          7.7
# 2  44984355   2009-08-24 21:45:00.00000061         12.9
# 3  25894730    2009-06-26 08:22:21.0000001          5.3
# 4  17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %% [markdown]
# ### Contexto
# El proyecto trata sobre **Uber Inc.**, la compañía de taxis más grande del mundo. En este trabajo, nuestro objetivo es **predecir la tarifa de futuros viajes**.
#
# Uber brinda servicio a millones de clientes cada día, por lo que gestionar adecuadamente sus datos es clave para desarrollar nuevas estrategias de negocio y obtener mejores resultados.
#
# ### Variables del conjunto de datos
#
# **Variables explicativas:**
# - **key**: identificador único de cada viaje.
# - **pickup_datetime**: fecha y hora en que se inició el viaje.
# - **passenger_count**: cantidad de pasajeros en el vehículo (dato ingresado por el conductor).
# - **pickup_longitude**: longitud del punto de inicio del viaje.
# - **pickup_latitude**: latitud del punto de inicio del viaje.
# - **dropoff_longitude**: longitud del punto de destino.
# - **dropoff_latitude**: latitud del punto de destino.
#
# **Variable objetivo (target):**
# - **fare_amount**: costo del viaje en dólares.

# %% [markdown]
# #### **Visualización de los datos** (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                200000 non-null  int64
#  1   date               200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %% [markdown]
# Se observan muy pocos datos nulos en las columnas relacionadas a la bajada de los viajes. Se continúa con las métricas generales de las columnas numéricas.

# %%
df.describe()
# Out:
#                 key    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991407         40.733823         1.000000
# 50%           -73.980093         40.753042         1.000000
# 75%           -73.963658         40.768001         2.000000
# max          1153.572603        872.697628       208.000000

# %% [markdown]
# Siendo que la variable objetivo es **fare_amount**, y observando que tiene datos negativos, se decide eliminarlos ya que no hay una manera viable de imputarlos.

# %%
df = df[df['fare_amount']>=0]

# %% [markdown]
# Se continúa con los valores nulos para luego eliminarlos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 199983 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                199983 non-null  int64
#  1   date               199983 non-null  object
#  2   fare_amount        199983 non-null  float64
#  3   pickup_datetime    199983 non-null  object
#  4   pickup_longitude   199983 non-null  float64
#  5   pickup_latitude    199983 non-null  float64
#  6   dropoff_longitude  199982 non-null  float64
#  7   dropoff_latitude   199982 non-null  float64
#  8   passenger_count    199983 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 15.3+ MB

# %%
df[df.isna().any(axis=1)]
# Out:
#             key                         date  fare_amount  \
# 87946  32736015  2013-07-02 03:51:57.0000001         24.1
#
#                pickup_datetime  pickup_longitude  pickup_latitude  \
# 87946  2013-07-02 03:51:57 UTC        -73.950581        40.779692
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# 87946                NaN               NaN                0

# %%
df = df.dropna()

# %% [markdown]
# **Creación de nuevas variables**

# %% [markdown]
# Se adecúan los tipos de datos para la creación de columnas relacionadas al tiempo y la distancia.

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'], utc=True)

# %% [markdown]
# Para evitar datos redundantes, se elimina la columna **date**. También **key**, al ser irrelevante.

# %%
df = df.drop(columns=['date', 'key'])

# %% [markdown]
# Para descartar ideas innecesarias a la hora de crear varialbles nuevas, se visualizan las variaciones de **fare_amount** con respecto a la hora y el día de la semana.

# %%
prov = df.copy()

# %%
prov['hora'] = prov['pickup_datetime'].dt.hour

# %%
tarifa_hora = prov.groupby('hora')['fare_amount'].mean()
tarifa_hora.head(24)
# Out:
# hora
# 0     11.656280
# 1     11.663277
# 2     11.449889
# 3     11.726272
# 4     14.142001
# 5     16.016841
# 6     11.920382
# 7     11.124822
# 8     10.906040
# 9     10.948391
# 10    11.028997
# 11    11.192338
# 12    11.171030
# 13    11.477327
# 14    11.977694
# 15    11.942214
# 16    11.793926
# 17    11.486387
# 18    10.920056
# 19    10.567703
# 20    10.799106
# 21    10.961904
# 22    11.308012
# 23    11.580917
# Name: fare_amount, dtype: float64

# %%
tarifa_hora.plot(kind='bar', figsize=(6, 5), color='skyblue', edgecolor='black')
# Out:
# <Axes: xlabel='hora'>

# %% [markdown]
# Teniendo en cuenta el cálculo agrupado y el gráfico anterior, la variación más significativa se produce entre las 4 y 5 de la madrugada. El resto del día se mantiene bastante estable. Sin embargo, se podrían considerar destacables las franjas de 00 a 03 y 14 a 16. Se tendrá en cuenta para dummies.

# %%
prov['dia'] = prov['pickup_datetime'].dt.dayofweek

# %%
tarifa_dia = prov.groupby('dia')['fare_amount'].mean()
tarifa_dia.head(7)
# Out:
# dia
# 0    11.381039
# 1    11.081540
# 2    11.352601
# 3    11.519246
# 4    11.444573
# 5    11.032273
# 6    11.757021
# Name: fare_amount, dtype: float64

# %%
tarifa_dia = prov.groupby('dia')['fare_amount'].mean()
tarifa_dia.plot(kind='bar', figsize=(6,4), color='skyblue', edgecolor='black')
# Out:
# <Axes: xlabel='dia'>

# %% [markdown]
# El promedio de la tarifa por día no parece tener una gran variación por día, salvo levemente por los domingos. Se evaluará si realmente tiene impacto para un modelo predictivo.

# %%
prov['quincena'] = prov['pickup_datetime'].dt.day.apply(lambda d: 1 if d <= 15 else 2)

# %%
tarifa_quincena = prov.groupby('quincena')['fare_amount'].mean()
tarifa_quincena.head()
# Out:
# quincena
# 1    11.338007
# 2    11.385958
# Name: fare_amount, dtype: float64

# %% [markdown]
# Asimismo, la quincena del mes en el que se ubica el viaje tampoco parece tener relevancia. Se descarta para hacer dummies.

# %% [markdown]
# Se crea una columna para conocer bien los KMs hechos por viaje.

# %%
def manhattan_distance(lat1, lon1, lat2, lon2):
    R = 6371  # radio de la Tierra en km
    # Convertir a radianes
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])

    dlat = np.abs(lat2 - lat1)
    dlon = np.abs(lon2 - lon1)

    # Distancia latitudinal
    a_lat = np.sin(dlat/2.0)**2
    c_lat = 2 * np.arcsin(np.sqrt(np.clip(a_lat, 0, 1)))
    dist_lat = R * c_lat

    # Distancia longitudinal (ajustada por latitudes)
    a_lon = np.sin(dlon/2.0)**2 * np.cos(lat1) * np.cos(lat2)
    c_lon = 2 * np.arcsin(np.sqrt(np.clip(a_lon, 0, 1)))
    dist_lon = R * c_lon

    return dist_lat + dist_lon

df['KMs'] = manhattan_distance(
    df['pickup_latitude'], df['pickup_longitude'],
    df['dropoff_latitude'], df['dropoff_longitude'])

# %% [markdown]
# Se chequea cómo son las métricas del dataset actualizado.

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  199982.000000     199982.000000    199982.000000      199982.000000
# mean       11.362302        -72.527508        39.935812         -72.525538
# std         9.897102         11.438294         7.720883          13.116956
# min         0.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734795         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980092
# 75%        12.500000        -73.967154        40.767158         -73.963658
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count            KMs
# count     199982.000000    199982.000000  199982.000000
# mean          39.924024         1.684502      26.996818
# std            6.794527         1.385977     501.917340
# min         -881.985513         0.000000       0.000000
# 25%           40.733824         1.000000       1.550049
# 50%           40.753042         1.000000       2.720959
# 75%           40.768001         2.000000       4.993165
# max          872.697628       208.000000   18829.539706

# %% [markdown]
# Se destaca que **fare_amount** tiene valores en cero. Se teoriza si son viajes con KMs hechos. En el caso de que haya, se eliminan por no aportar nada al futuro modelo, siendo posiblemente errores.

# %%
df[(df['KMs']==0) & (df['fare_amount']==0)]
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 20744           0.0 2015-04-22 23:25:07+00:00        -73.658897
# 197172          0.0 2015-02-13 07:35:32+00:00          0.000000
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 20744         40.805199         -73.658897         40.805199                1
# 197172         0.000000           0.000000          0.000000                5
#
#         KMs
# 20744   0.0
# 197172  0.0

# %%
df = df[~((df['KMs'] == 0) & (df['fare_amount'] == 0))]

# %% [markdown]
# **Creación de dummies**

# %% [markdown]
# Se agregan columnas relacionadas a días (y si el viaje se produjo un domingo o no) y horas (y si se produjo en el pico encontrado o no), ya que se consideran valores importantes para el modelo predictivo buscado.

# %%
df['hour'] = df['pickup_datetime'].dt.hour   # variable provisaria
df['day'] = df['pickup_datetime'].dt.dayofweek   # variable provisoria
df['es_domingo'] = df['day'] == 6
df['franja_pico_madrugada'] = (df['hour'] >= 4) & (df['hour'] <= 5)     # pico visto en madrugada

# %%
condic_hora = [
    (df['hour']>=0) & (df['hour']<=3),
    (df['hour']>=4) & (df['hour']<=5),
    (df['hour']>=14) & (df['hour']<=16)
]
valores = ['resto_madrugada', 'pico_madrugada', 'pico_tarde']

df['franja_hora'] = np.select(condic_hora, valores, default='resto_horas')

# %%
df = df.drop(columns=['hour'])

# %% [markdown]
# Tras una breve investigación externa, se llegó a la conclusión de que la variable **passenger_count** si bien aparece como numérica, en realidad se puede tomar como categórica. La cantidad de pasajeros solo define si el viaje implica el uso de un auto normal o un auto más amplio. Por esta razón, se procede a transformarla en dummies más acordes.
# - Paquetería = 0 pasajeros
# - UberX = 1 a 4 pasajeros
# - UberXL = 5 o más pasajeros.

# %%
condiciones = [
    (df['passenger_count'] == 0),
    (df['passenger_count']>=1) & (df['passenger_count']<=4),
    (df['passenger_count'] >=5)
]
valores = ['paqueteria', 'uberx', 'uberxl']

df['tipo_viaje'] = np.select(condiciones, valores, default='otro')

# %%
df = df.drop(columns=['passenger_count'])

# %% [markdown]
# Se transforman las variables nuevas a dummies.

# %%
df_dummies = df.copy()

# %%
dummies_tipo = pd.get_dummies(df_dummies['tipo_viaje'], prefix='tipo_viaje', drop_first=False)
df_dummies = pd.concat([df_dummies, dummies_tipo], axis=1)

# %%
dummies_franja = pd.get_dummies(df_dummies['franja_hora'], prefix='franja', drop_first=True)
df_dummies = pd.concat([df_dummies, dummies_franja], axis=1)

# %%
df_dummies = df_dummies.drop(columns=['tipo_viaje', 'franja_hora'])

# %%
df_dummies.columns
# Out:
# Index(['fare_amount', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'KMs', 'es_domingo',
#        'franja_pico_madrugada', 'tipo_viaje_paqueteria', 'tipo_viaje_uberx',
#        'tipo_viaje_uberxl', 'franja_pico_tarde', 'franja_resto_horas',
#        'franja_resto_madrugada'],
#       dtype='object')

# %%
df_dummies = df_dummies.drop(columns=['pickup_datetime', 'day'])

# %% [markdown]
# Se sospecha que KMs pude ser muy importante para el modelo pero antes, se continuará viendo su distribución para ver si se necesita escalamiento.

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_dummies['KMs'])
plt.title('Distribución de KMs')
plt.xlabel('Kilómetros')
plt.show()

# %%
scaler = StandardScaler()

df_dummies['KMs_scaled'] = scaler.fit_transform(df_dummies[['KMs']])

# %%
df_final = df_dummies.drop(columns=['KMs', 'pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude'])

# %% [markdown]
# **Correlaciones entre variables candidatas**

# %%
matriz_corr = df_final.corr()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(matriz_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlaciones entre variables numéricas')
plt.show()

# %% [markdown]
# #### División de dataset a train y test

# %%
y = df_final['fare_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_final.drop(columns='fare_amount'), df_final['fare_amount'], test_size=0.2, random_state=42)

# %%
print(f'Tamaño de X_train {X_train.shape}; tamaño de X_test: {X_test.shape}')
# Out:
# Tamaño de X_train (159984, 9); tamaño de X_test: (39996, 9)

# %% [markdown]
# **Examinación de estructura y contenido de variables de X_train**

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159984 entries, 84442 to 121968
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   es_domingo              159984 non-null  bool
#  1   franja_pico_madrugada   159984 non-null  bool
#  2   tipo_viaje_paqueteria   159984 non-null  bool
#  3   tipo_viaje_uberx        159984 non-null  bool
#  4   tipo_viaje_uberxl       159984 non-null  bool
#  5   franja_pico_tarde       159984 non-null  bool
#  6   franja_resto_horas      159984 non-null  bool
#  7   franja_resto_madrugada  159984 non-null  bool
#  8   KMs_scaled              159984 non-null  float64
# dtypes: bool(8), float64(1)
# memory usage: 3.7 MB

# %% [markdown]
# #### Modelado Inicial

# %% [markdown]
# Se asegura que todas los columnas cuenten con la misma escala, por lo que se hace un **escalado de X_train**.

# %%
scaler = StandardScaler()
scaler.fit(X_train)

# Transformamos ambos conjuntos usando la media y desv. del train
X_train_scaled = scaler.transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %%
# Definición y entrenamiento
model = LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Evaluación

# %%
# Predicciones
y_train_pred = model.predict(X_train_scaled)
y_test_pred  = model.predict(X_test_scaled)

# Métricas
def evaluar_modelo(y_true, y_pred, nombre="modelo"):
    mse  = mean_squared_error(y_true, y_pred)
    rmse = mse**0.5
    mae  = mean_absolute_error(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)
    print(f"Resultados {nombre}:")
    print(f"  MSE : {mse:.4f}")
    print(f"  RMSE: {rmse:.4f}")
    print(f"  MAE : {mae:.4f}")
    print(f"  R²  : {r2:.4f}")
    print("-"*40)

evaluar_modelo(y_train, y_train_pred, "LinearRegression (train)")
evaluar_modelo(y_test, y_test_pred, "LinearRegression (test)")
# Out:
# Resultados LinearRegression (train):
#   MSE : 98.4383
#   RMSE: 9.9216
#   MAE : 6.0369
#   R²  : 0.0048
# ----------------------------------------
# Resultados LinearRegression (test):
#   MSE : 93.6740
#   RMSE: 9.6785
#   MAE : 6.0206
#   R²  : 0.0047
# ----------------------------------------

# %% [markdown]
# **Observaciones**: (completar)

# %% [markdown]
# **Prueba con métodos de gradiente descendiente**

# %%
from sklearn.linear_model import SGDRegressor

# %%
m, n = X_train_scaled.shape

# Agregar columna de 1s
X_train_bias = np.c_[np.ones((m,1)), X_train_scaled]
X_test_bias  = np.c_[np.ones((len(X_test_scaled),1)), X_test_scaled]

# Asegurar que y sean np.array columnas
y_train = np.asarray(y_train).reshape(-1,1)
y_test  = np.asarray(y_test).reshape(-1,1)

# Inicialización
theta_batch = np.random.randn(n+1,1)
theta_sgd   = np.random.randn(n+1,1)
theta_mbgd  = np.random.randn(n+1,1)

n_epochs = 50   # ⚠️ bajar épocas para datasets grandes
eta = 0.1
batch_size = 64

errors = {"batch": [], "sgd": [], "minibatch": []}

for epoch in range(n_epochs):
    # --- Batch GD (solo si no explota memoria) ---
    grad_batch = 2/m * X_train_bias.T.dot(X_train_bias.dot(theta_batch) - y_train)
    theta_batch -= eta * grad_batch

    # --- SGD ---
    i = np.random.randint(m)
    xi = X_train_bias[i:i+1]
    yi = y_train[i:i+1]
    grad_sgd = 2 * xi.T.dot(xi.dot(theta_sgd) - yi)
    theta_sgd -= eta * grad_sgd

    # --- Mini-Batch ---
    indices = np.random.randint(m, size=batch_size)
    xi = X_train_bias[indices]
    yi = y_train[indices]
    grad_mbgd = 2/batch_size * xi.T.dot(xi.dot(theta_mbgd) - yi)
    theta_mbgd -= eta * grad_mbgd

    # Calcular errores en test
    y_pred_batch = X_test_bias.dot(theta_batch)
    y_pred_sgd   = X_test_bias.dot(theta_sgd)
    y_pred_mbgd  = X_test_bias.dot(theta_mbgd)

    errors["batch"].append(mean_squared_error(y_test, y_pred_batch))
    errors["sgd"].append(mean_squared_error(y_test, y_pred_sgd))
    errors["minibatch"].append(mean_squared_error(y_test, y_pred_mbgd))

# Graficar
plt.plot(range(1, n_epochs+1), errors["batch"], label="Batch GD")
plt.plot(range(1, n_epochs+1), errors["sgd"], label="SGD")
plt.plot(range(1, n_epochs+1), errors["minibatch"], label="Mini-Batch GD")
plt.xlabel("Épocas")
plt.ylabel("Error (MSE en test)")
plt.title("Comparación: Batch, SGD y Mini-Batch Gradient Descent")
plt.legend()
plt.show()

# %% [markdown]
# **Observaciones:** (completar)

# %% [markdown]
# **Se prueba con métodos de regularización (Lasso, Ridge, Elastic Net)**

# %%
n_epochs = 50
batch_size = 64
etas = [0.1, 0.01, 0.001]   # diferentes learning rates
decay = 0.001               # para SGD con decaimiento


# Lista de resultados
resultados = []

for eta in etas:
    # Inicialización de parámetros
    theta_batch = np.random.randn(n+1,1)
    theta_sgd   = np.random.randn(n+1,1)
    theta_mbgd  = np.random.randn(n+1,1)

    for epoch in range(n_epochs):
        # ---- Batch GD ----
        grad_batch = 2/m * X_train_bias.T.dot(X_train_bias.dot(theta_batch) - y_train)
        theta_batch -= eta * grad_batch

        # ---- SGD ----
        i = np.random.randint(m)
        xi = X_train_bias[i:i+1]
        yi = y_train[i:i+1]
        eta_epoch = eta / (1 + decay * epoch)  # con scheduler
        grad_sgd = 2 * xi.T.dot(xi.dot(theta_sgd) - yi)
        theta_sgd -= eta_epoch * grad_sgd

        # ---- Mini-Batch GD ----
        indices = np.random.randint(m, size=batch_size)
        xi = X_train_bias[indices]
        yi = y_train[indices]
        grad_mbgd = 2/batch_size * xi.T.dot(xi.dot(theta_mbgd) - yi)
        theta_mbgd -= eta * grad_mbgd


    # Evaluación final

    for modelo, theta in [("Batch GD", theta_batch),
                          ("SGD", theta_sgd),
                          ("Mini-Batch GD", theta_mbgd)]:
        for conj, Xb, yb in [("Train", X_train_bias, y_train),
                             ("Test",  X_test_bias,  y_test)]:
            y_pred = Xb.dot(theta)
            resultados.append({
                "Modelo": modelo,
                "LearningRate": eta,
                "Conjunto": conj,
                "MSE": mean_squared_error(yb, y_pred),
                "RMSE": mean_squared_error(yb, y_pred, squared=False),
                "MAE": mean_absolute_error(yb, y_pred),
                "R²": r2_score(yb, y_pred)
            })


# DataFrame de salida
df_resultados = pd.DataFrame(resultados)
df_resultados = df_resultados.sort_values(by=["Modelo","LearningRate","Conjunto"]).reset_index(drop=True)

df_resultados
# Out:
#            Modelo  LearningRate Conjunto            MSE        RMSE  \
# 0        Batch GD         0.001     Test     181.376499   13.467609
# 1        Batch GD         0.001    Train     186.216892   13.646131
# 2        Batch GD         0.010     Test     110.534751   10.513551
# 3        Batch GD         0.010    Train     115.512604   10.747679
# 4        Batch GD         0.100     Test      93.674941    9.678582
# 5        Batch GD         0.100    Train      98.437960    9.921591
# 6   Mini-Batch GD         0.001     Test     214.686753   14.652193
# 7   Mini-Batch GD         0.001    Train     218.590349   14.784801
# 8   Mini-Batch GD         0.010     Test     112.327936   10.598487
# 9   Mini-Batch GD         0.010    Train     117.064739   10.819646
# 10  Mini-Batch GD         0.100     Test      98.556921    9.927584
# 11  Mini-Batch GD         0.100    Train     103.697577   10.183201
# 12            SGD         0.001     Test     218.074010   14.767329
# 13            SGD         0.001    Train     222.872564   14.928917
# 14            SGD         0.010     Test     141.753611   11.906033
# 15            SGD         0.010    Train     149.388624   12.222464
# 16            SGD         0.100     Test  294472.104037  542.652839
# 17            SGD         0.100    Train  295002.794603  543.141597
#
#            MAE           R²
# 0     9.322191    -0.927223
# 1     9.324648    -0.882661
# 2     5.545002    -0.174491
# 3     5.564398    -0.167837
# 4     6.021066     0.004653
# 5     6.037304     0.004788
# 6    10.642711    -1.281163
# 7    10.625803    -1.209958
# 8     5.605979    -0.193545
# 9     5.612682    -0.183529
# 10    6.116906    -0.047221
# 11    6.138334    -0.048387
# 12   10.944999    -1.317154
# 13   10.940431    -1.253251
# 14    6.541761    -0.506209
# 15    6.580986    -0.510325
# 16  284.761467 -3127.925147
# 17  284.961433 -2981.490635

# %% [markdown]
# **Observaciones**: (completar)

# %% [markdown]
# **Visualización de residuos**

# %% [markdown]
# **Observaciones**: (completar)

# %% [markdown]
# #### Optimización de hiperparámetros

# %% [markdown]
# #### Comparación de modelos
