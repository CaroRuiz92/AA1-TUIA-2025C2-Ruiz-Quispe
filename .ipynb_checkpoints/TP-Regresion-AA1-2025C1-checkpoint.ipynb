# %% [markdown]
# ## Trabajo Práctico
# ### Aprendizaje Automático I

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler   # u otros scalers
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet, LassoCV, RidgeCV, ElasticNetCV
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #### Carga de datos

# %%
file_path = 'uber_fares.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# Visualización general del dataset.

# %%
df.head()
# Out:
#         key                           date  fare_amount  \
# 0  24238194    2015-05-07 19:52:06.0000003          7.5
# 1  27835199    2009-07-17 20:04:56.0000002          7.7
# 2  44984355   2009-08-24 21:45:00.00000061         12.9
# 3  25894730    2009-06-26 08:22:21.0000001          5.3
# 4  17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# ...

# %% [markdown]
# #### Contexto
# El proyecto trata sobre **Uber Inc.**, la compañía de taxis más grande del mundo. En este trabajo, nuestro objetivo es **predecir la tarifa de futuros viajes**.
#
# Uber brinda servicio a millones de clientes cada día, por lo que gestionar adecuadamente sus datos es clave para desarrollar nuevas estrategias de negocio y obtener mejores resultados.
#
# ### Variables del conjunto de datos
#
# **Variables explicativas:**
# - **key**: identificador único de cada viaje.
# - **pickup_datetime**: fecha y hora en que se inició el viaje.
# - **passenger_count**: cantidad de pasajeros en el vehículo (dato ingresado por el conductor).
# - **pickup_longitude**: longitud del punto de inicio del viaje.
# - **pickup_latitude**: latitud del punto de inicio del viaje.
# - **dropoff_longitude**: longitud del punto de destino.
# - **dropoff_latitude**: latitud del punto de destino.
#
# **Variable objetivo (target):**
# - **fare_amount**: costo del viaje en dólares.

# %% [markdown]
# **Visualización de los datos**

# %%
df.describe()
# Out:
#                 key    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# ...

# %% [markdown]
# Siendo que la variable objetivo es **fare_amount**, y observando que tiene datos negativos, se decide eliminarlos ya que no hay una maner aviable de imputarlos.

# %%
df = df[df['fare_amount']>=0]

# %% [markdown]
# Se continúa con los valores nulos para luego eliminarlos.

# %%
df.isna().sum()
# Out:
# key                  0
# date                 0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#             key                         date  fare_amount  \
# 87946  32736015  2013-07-02 03:51:57.0000001         24.1
#
#                pickup_datetime  pickup_longitude  pickup_latitude  \
# 87946  2013-07-02 03:51:57 UTC        -73.950581        40.779692
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# 87946                NaN               NaN                0

# %%
df = df.dropna()

# %% [markdown]
# **Creación de nuevas variables**

# %% [markdown]
# Se adecúan los tipos de datos para la creación de columnas relacionadas al tiempo y la distancia.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 199982 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                199982 non-null  int64
#  1   date               199982 non-null  object
#  2   fare_amount        199982 non-null  float64
#  3   pickup_datetime    199982 non-null  object
#  4   pickup_longitude   199982 non-null  float64
#  5   pickup_latitude    199982 non-null  float64
#  6   dropoff_longitude  199982 non-null  float64
#  7   dropoff_latitude   199982 non-null  float64
#  8   passenger_count    199982 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 15.3+ MB

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'], utc=True)

# %% [markdown]
# Para evitar datos redundantes, se elimina la columna **date**. También **key**, al ser irrelevante.

# %%
df = df.drop(columns=['date', 'key'])

# %% [markdown]
# Se crea una columna para conocer bien los KMs hechos por viaje.

# %%
def manhattan_distance(lat1, lon1, lat2, lon2):
    R = 6371  # radio de la Tierra en km
    # Convertir a radianes
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])

    dlat = np.abs(lat2 - lat1)
    dlon = np.abs(lon2 - lon1)

    # Distancia latitudinal
    a_lat = np.sin(dlat/2.0)**2
    c_lat = 2 * np.arcsin(np.sqrt(np.clip(a_lat, 0, 1)))
    dist_lat = R * c_lat

    # Distancia longitudinal (ajustada por latitudes)
    a_lon = np.sin(dlon/2.0)**2 * np.cos(lat1) * np.cos(lat2)
    c_lon = 2 * np.arcsin(np.sqrt(np.clip(a_lon, 0, 1)))
    dist_lon = R * c_lon

    return dist_lat + dist_lon

df['KMs'] = manhattan_distance(
    df['pickup_latitude'], df['pickup_longitude'],
    df['dropoff_latitude'], df['dropoff_longitude'])

# %% [markdown]
# Se agregan columnas relacionadas a días (y si el viaje se produjo un fin de semana) y horas (y si se produjo de noche o día), ya que se consideran valores importantes para el modelo predictivo buscado.

# %%
df['hour'] = df['pickup_datetime'].dt.hour   # variable provisaria
df['day'] = df['pickup_datetime'].dt.dayofweek   # variable provisoria
df['is_weekend'] = df['day'] >= 5     # True si es viernes, sábado o domingo
df['is_night'] = (df['hour'] >= 22) | (df['hour'] < 6)     # nocturno: 22 a 6
df['quincena'] = df['pickup_datetime'].dt.day.apply(lambda d: 1 if d <= 15 else 2)   # 1 1° quincena, 2 2° quincena

# %% [markdown]
# Al ser ya innecesarias, se eliminan la columna **hour** y **day**.

# %%
df = df.drop(columns=['hour', 'day'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 199982 entries, 0 to 199999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        199982 non-null  float64
#  1   pickup_datetime    199982 non-null  datetime64[ns, UTC]
#  2   pickup_longitude   199982 non-null  float64
#  3   pickup_latitude    199982 non-null  float64
#  4   dropoff_longitude  199982 non-null  float64
#  5   dropoff_latitude   199982 non-null  float64
#  6   passenger_count    199982 non-null  int64
#  7   KMs                199982 non-null  float64
#  8   is_weekend         199982 non-null  bool
#  9   is_night           199982 non-null  bool
#  10  quincena           199982 non-null  int64
# dtypes: bool(2), datetime64[ns, UTC](1), float64(6), int64(2)
# memory usage: 15.6 MB

# %% [markdown]
# Se toman solo las variables numéricas y se chequean sus correlaciones.

# %%
df_limpio = df[['fare_amount', 'passenger_count', 'KMs', 'is_weekend', 'is_night', 'quincena']]

# %%
matriz_corr = df_limpio.corr()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(matriz_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlaciones entre variables numéricas')
plt.show()

# %% [markdown]
# #### División de dataset a train y test

# %%
y = df_limpio['fare_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_limpio.drop(columns='fare_amount'), df_limpio['fare_amount'], test_size=0.2, random_state=42)

# %% [markdown]
# **Examinación de estructura y contenido de variables**

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159985 entries, 15044 to 121967
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   passenger_count  159985 non-null  int64
#  1   KMs              159985 non-null  float64
#  2   is_weekend       159985 non-null  bool
#  3   is_night         159985 non-null  bool
#  4   quincena         159985 non-null  int64
# dtypes: bool(2), float64(1), int64(2)
# memory usage: 5.2 MB

# %%
X_train.describe()
# Out:
#        passenger_count            KMs       quincena
# count    159985.000000  159985.000000  159985.000000
# mean          1.684795      26.664604       1.506497
# std           1.404863     498.015905       0.499959
# min           0.000000       0.000000       1.000000
# 25%           1.000000       1.552478       1.000000
# 50%           1.000000       2.727439       2.000000
# 75%           2.000000       5.008773       2.000000
# max         208.000000   18829.539706       2.000000

# %% [markdown]
# A través de este último cuadro, se destacan datos atípicos relacionados a **passenger_count**.

# %% [markdown]
# **Visualización e imputación de valores atípicos**

# %%
# Distribución de la cantidad de pasajeros por viaje (passenger_count)
plt.figure(figsize=(12,6))
sns.boxplot(x=X_train['passenger_count'])
plt.title('Cantidad de viajeros por viaje')
plt.xlabel('Cantidad de pasajeros por viaje')
plt.show()

# %% [markdown]
# El anterior análisis es verificado por el boxplot. Passenger_count presenta solo un valor máximo (y atípico) de 208 viajeros en un viaje. Se observa cómo sería esta distribución sin dicho dato atípico.

# %%
# Se grafica para conocer la distribución sin dicho valor atípico
df_sin_atip_pass = X_train[X_train['passenger_count']<208]

# %%
# Distribución passenger_count sin el outlier encontrado
plt.figure(figsize=(10, 5))
sns.boxplot(x=df_sin_atip_pass['passenger_count'])
plt.title('Cantidad de viajeros por viaje (s/outlier)')
plt.xlabel('Cantidad de pasajeros por viaje')
plt.show()

# %% [markdown]
# Se puede teorizar que la cantidad 0 como cantidad de pasajeros pudo ser porque se transportó paquetería. Su valor máximo es 3 y ahora los valores atípicos se consideran más normales al ser de 4, 5 y 6 (posibles dentro de un solo auto XL). Se opta por imputar el atípico con el valor máximo de los outliers aceptados: 6.

# %%
X_train.loc[X_train['passenger_count']==208, 'passenger_count'] = 6

# %%
plt.boxplot(X_train['KMs'], vert=False)
plt.title('Distribución de KMs hechos por viaje')
plt.xlabel('KMs hechos')
plt.show()

# %% [markdown]
# Se observan muchos outiers relacionados a la cantidad de KMs hechos, esto puede darse porque es factible que haya viajes muy largos. Sin embargo, se destaca la existencia de viajes con 0 KMs hechos. Se procede a imputarlos.

# %%
print(f"De {len(X_train)} viajes, {len(X_train[X_train['KMs'] == 0])} tienen 0 KMs")
# Out:
# De 159985 viajes, 4522 tienen 0 KMs
